# %% [markdown]
# <a href="https://colab.research.google.com/github/pramit46/LLMTry/blob/main/ML/Linear_Regression_Weird.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/sample_data/california_housing_train.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df=df[["total_rooms","total_bedrooms"]]

# %%
plt.scatter(df['total_bedrooms'],df['total_rooms'], marker="+", color="red")
plt.xlabel("total_bedrooms")
plt.ylabel("total_rooms")
plt.show()

# %%
plt.hist(df['total_bedrooms'],bins=50,color="red")
#plt.plot(y_pred)
# Out:
# (array([7.630e+02, 2.286e+03, 4.035e+03, 3.439e+03, 2.182e+03, 1.425e+03,
#         8.920e+02, 5.070e+02, 3.560e+02, 2.790e+02, 1.940e+02, 1.370e+02,
#         1.130e+02, 8.000e+01, 5.300e+01, 4.700e+01, 2.600e+01, 3.200e+01,
#         1.800e+01, 2.900e+01, 2.100e+01, 1.300e+01, 1.200e+01, 1.100e+01,
#         5.000e+00, 6.000e+00, 6.000e+00, 4.000e+00, 4.000e+00, 2.000e+00,
#         5.000e+00, 3.000e+00, 3.000e+00, 1.000e+00, 4.000e+00, 0.000e+00,
#         0.000e+00, 2.000e+00, 2.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([1.00000e+00, 1.29880e+02, 2.58760e+02, 3.87640e+02, 5.16520e+02,
#         6.45400e+02, 7.74280e+02, 9.03160e+02, 1.03204e+03, 1.16092e+03,
#         1.28980e+03, 1.41868e+03, 1.54756e+03, 1.67644e+03, 1.80532e+03,
#         1.93420e+03, 2.06308e+03, 2.19196e+03, 2.32084e+03, 2.44972e+03,
# ...

# %%
plt.hist(df["total_rooms"],bins=50,color="brown",)
# Out:
# (array([1.141e+03, 3.493e+03, 4.695e+03, 3.069e+03, 1.839e+03, 9.610e+02,
#         5.300e+02, 3.380e+02, 2.600e+02, 1.590e+02, 1.080e+02, 8.300e+01,
#         7.000e+01, 5.500e+01, 3.200e+01, 2.500e+01, 1.800e+01, 1.600e+01,
#         1.500e+01, 1.300e+01, 1.200e+01, 1.300e+01, 9.000e+00, 9.000e+00,
#         7.000e+00, 4.000e+00, 4.000e+00, 6.000e+00, 2.000e+00, 1.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 2.000e+00, 2.000e+00, 0.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 2.000e+00, 0.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([2.00000e+00, 7.60700e+02, 1.51940e+03, 2.27810e+03, 3.03680e+03,
#         3.79550e+03, 4.55420e+03, 5.31290e+03, 6.07160e+03, 6.83030e+03,
#         7.58900e+03, 8.34770e+03, 9.10640e+03, 9.86510e+03, 1.06238e+04,
#         1.13825e+04, 1.21412e+04, 1.28999e+04, 1.36586e+04, 1.44173e+04,
# ...

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
X=df.drop("total_rooms", axis=1)
Y=df["total_rooms"]

# %%
from sklearn.preprocessing import StandardScaler

X=StandardScaler().fit_transform(X)

# %%
x_train, x_test, y_train,y_test= train_test_split(X,Y, test_size=0.25, random_state=42)
print(x_train.shape,type(x_train))
print(x_test.shape, type(x_test))
print(y_train.shape,type(y_train))
print(y_test.shape, type(y_test))
#print(y_pred.shape, type(y_pred))
# Out:
# (12750, 1) <class 'numpy.ndarray'>
# (4250, 1) <class 'numpy.ndarray'>
# (12750,) <class 'pandas.core.series.Series'>
# (4250,) <class 'pandas.core.series.Series'>

# %%
x_test
# Out:
# array([[ 0.90296765],
#        [-0.2785633 ],
#        [ 0.47353572],
#        ...,
#        [-1.05913294],
#        [ 0.42371213],
#        [-0.42328898]])

# %%
y_test
# Out:
# 10941    4838.0
# 5250     2742.0
# 10292    3705.0
# 2266     5455.0
# 6398     1331.0
#           ...
# 13303    3937.0
# 4106     3419.0
# 10926     508.0
# 4344     3308.0
# 216      1867.0
# Name: total_rooms, Length: 4250, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
y_test
# Out:
# 10941    4838.0
# 5250     2742.0
# 10292    3705.0
# 2266     5455.0
# 6398     1331.0
#           ...
# 13303    3937.0
# 4106     3419.0
# 10926     508.0
# 4344     3308.0
# 216      1867.0
# Name: total_rooms, Length: 4250, dtype: float64

# %%
import numpy as np
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
np.array(x_train).reshape(-1,1).shape
# Out:
# (12750, 1)

# %%
np.array(x_train).shape
# Out:
# (12750, 1)

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([4457.46410548, 2077.01132134, 3592.27945903, ...,  504.38287559,
#        3491.89891994, 1785.42975541])

# %%
type(y_test)
y_pred.shape
# Out:
# (4250,)

# %%
#plt.plot([min(y_pred), max(y_pred)], [min(y_pred), max(y_pred)], color='red', linestyle='--')
plt.plot(x_test, y_pred, color="green", marker="^", label="Regression Line")
plt.scatter(x_train, y_train, marker="h", color="red", label="Test Data")
plt.xticks(rotation=45)
plt.xlabel("x_test")
plt.ylabel("y_test")
plt.title('Linear Regression')

plt.legend()
plt.show()

# %%
plt.scatter(x_test, y_test, label='Test Data',marker="^")
plt.plot(x_test, y_pred, color='red', marker="+",label='Regression Line')
plt.xlabel('X')

plt.ylabel('Y')

plt.legend()
plt.show()

# %%
plt.plot(x_test, y_pred)
plt.scatter(x_test, y_test)

# %%
print(lr.predict([[174]]))
# Out:
# [353199.33359696]

# %%
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score,mean_absolute_error

# %%
def eval_metrics(actual, pred):
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    r2 = r2_score(actual, pred)
    #acc= accuracy_score(actual, pred)
    return rmse, mae, r2

# %%
print(eval_metrics(y_test,y_pred))
# Out:
# (811.6087367846811, 496.35785398278966, 0.8584832261127175)

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [2014.7189398]
# 2638.238071856463

# %%
import matplotlib.pyplot as plt
import numpy as np

x_axis = np.arange(len(y_test))
plt.figure(figsize=(6, 6))
plt.scatter(x_axis, y_test, label='Actual', color='blue')
plt.scatter(x_axis, y_pred, label='Predicted', color='green')

plt.xlabel('Index')
plt.ylabel('Composite Score')
plt.title('Actual vs Predicted Values')

plt.legend()
plt.show()

# %%
from sklearn.linear_model import ElasticNet

# %%
el_model=ElasticNet(alpha=10,l1_ratio=0.9)

# %%
el_model.fit(x_train,y_train)
# Out:
# ElasticNet(alpha=10, l1_ratio=0.9)

# %%
y_pred_el=el_model.predict(x_test)

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test, y_pred_el)
